# %%
import os
import pandas as pd
from glob import glob

# %% [markdown]
# #### Load Reviews csv

# %%
home_dir = 'c:\\Users\\DanaTal\\projects\\nlp\\Bridezilla_NLP'
os.path.exists(home_dir)
data_dir = os.path.join(home_dir, f'data')
data_path = glob(data_dir + '\\summary_test.csv')[0]
print(data_path)
data_path

df = pd.read_csv(data_path)
print(f' number of reviews is: {len(df)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\DanaTal\projects\nlp\Bridezilla_NLP\summarize\test_summarization_models.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/test_summarization_models.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> home_dir = 'c:\\Users\\DanaTal\\projects\\nlp\\Bridezilla_NLP'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/test_summarization_models.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> os.path.exists(home_dir)
#       <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/test_summarization_models.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> data_dir = os.path.join(home_dir, f'data')
#       <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/test_summarization_models.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> data_path = glob(data_dir + '\\summary_test.csv')[0]
#
# NameError: name 'os' is not defined

# %% [markdown]
# I used this article for the summerization task:
#
# https://medium.com/@sarowar.saurav10/6-useful-text-summarization-algorithm-in-python-dfc8a9d33074

# %%
def summarize(df: pd.DataFrame, tokenizer, model, config: dict) -> pd.DataFrame:
    """ 
    """
    for i, row in df.iterrows():
        sequence = row.text
        input = tokenizer.encode("summarize: " + sequence, return_tensors='pt', max_length=config['max_input_length'], truncation=config['trunc_input'])
        output = model.generate(input, max_length=config['max_output_length'], min_length=config['min_output_length'], length_penalty=config['length_penalty'], num_beams=config['num_beams'])
        summary = tokenizer.decode(output[0])
        # remove tresh from the str
        df.at[i, "summary"] = summary.split(">")[1].split("<")[0]
    return df

# %% [markdown]
# ### T5 Abstractive Summarization

# %%
# T5 imports
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
# Load Tokenizer & model
model_name = 't5-small'
tokenizer = T5Tokenizer.from_pretrained(model_name)
model =  T5ForConditionalGeneration.from_pretrained(model_name, return_dict=True)

# I chose this hypper parameters for the model
T5_config = {'max_input_length':1024, 'trunc_input':True, 'max_output_length':100, 'min_output_length':1, 'length_penalty':5, 'num_beams':2}
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
df = df.rename(columns={"Review":"text"})

# %%
# Infer T5 model 
summarize(df, tokenizer, model, T5_config)
# Out:
#                                                  text  \
# 0   We love The Old Phoenix - this is the fourth t...
# 1   What a disappointment. We have wanted to stay ...
# 2   We walked over to Fenix from Loutro and stayed...
# 3   The Old Phoenix was the low point of our two w...
# 4   I had a fantastic time at Old-Phoenix!\n The b...
# 5   On the way from Marmara to Loutro I stopped fo...
# 6   If you are looking for a get away from it all ...
# 7   Amazing place with nice people running it! Ver...
# 8   When the small boat takes you into Finix Bay i...
# 9   I recommend this place for those who love to s...
# 10  Excellent stay! Fantastic view from the verand...
# 11  Owner was available and accommodating during e...
# 12  Just steps from the beach Villa Niki was spaci...
# 13  Andreas and his wife are amazing warm and frie...
# 14  It couldn't be more welcoming in a guest house...
# 15  This is a very clean and friendly "Rooms to le...
# 16  Great, family run hotel full of character, a l...
# 17  Like all the other reviews mention, Andreas an...
# 18  Excellent! There are two main reasons - I beli...
# 19  We spent 1 night here: we had a super nice roo...
#
#                          distilbart (arielle) summary  \
# 0   We love The Old Phoenix - this is the fourth t...
# 1   Rooms are tired,  beds uncomfortable,  bathroo...
# 2   We stayed on the beach by the Old Phoenix in C...
# 3   The Old Phoenix was the low point of our two w...
# 4   The traditional regional Greek cuisine at the ...
# 5   On the way from Marmara to Loutro I stopped fo...
# 6   The Pheonix is a great base for walking but in...
# 7   The food was also amazing, skip the menu and j...
# 8   Finix Bay is a wonderfully relaxing traditiona...
# 9   This is definitely the best place ever for sta...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#     (FILL IN MODEL NAME) summary  (FILL IN MODEL NAME) summary.1  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             NaN
# 7                            NaN                             NaN
# 8                            NaN                             NaN
# 9                            NaN                             NaN
# 10                           NaN                             NaN
# 11                           NaN                             NaN
# 12                           NaN                             NaN
# 13                           NaN                             NaN
# 14                           NaN                             NaN
# 15                           NaN                             NaN
# 16                           NaN                             NaN
# 17                           NaN                             NaN
# 18                           NaN                             NaN
# 19                           NaN                             NaN
#
#     (FILL IN MODEL NAME) summary.2  (FILL IN MODEL NAME) summary.3  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# 5                              NaN                             NaN
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                             NaN                             NaN
# 11                             NaN                             NaN
# 12                             NaN                             NaN
# 13                             NaN                             NaN
# 14                             NaN                             NaN
# 15                             NaN                             NaN
# 16                             NaN                             NaN
# 17                             NaN                             NaN
# 18                             NaN                             NaN
# 19                             NaN                             NaN
#
#     (FILL IN MODEL NAME) summary.4  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
#
#                                               summary
# 0    this is the fourth time we've visited the old...
# 1    we have wanted to stay here for years but it ...
# 2    we walked over to stony beach from Loutro and...
# 3    the old Phoenix was the low point of our two ...
# 4    the staff was incredibly friendly and attenti...
# 5   a waiter came to pay for a coffee and a yogurt...
# 6    we originally came here because itâ€TMs a gre...
# 7    the food was amazing, skip the menu and just ...
# 8    the small boat takes you into Finix Bay and t...
# 9    this is definitely the best place for those w...
# 10   the owner was very helpful and service orient...
# 11  owner was available and accommodating during e...
# 12  Andreas was very helpful and helpful. he was v...
# 13   the location is very quit and not too hot dur...
# 14   the room is spacious and the beds very clean....
# 15   this is a very clean and friendly "Rooms to l...
# 16  a little more set back on the hillside in Lout...
# 17   Andreas and his wife are extremely pleasant a...
# 18   the owners have been very helpful and trouble...
# 19   we spent 1 night here: we had a super nice ro...

# %%
# Save the output
summariztion_output_dir = os.path.join(home_dir, f"outputs\\summarization")
os.makedirs(summariztion_output_dir, exist_ok=True)

# %%
business_name = data_path.split('\\')[-1].split('.')[0]
summariztion_output_path = os.path.join(summariztion_output_dir, f'{model_name}_{business_name}.csv')
df.to_csv(summariztion_output_path)

# %% [markdown]
# #### BART Abstractive Summarization

# %%
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration

model_name = "ainize/bart-base-cnn"
#  Load Model and Tokenize
tokenizer = PreTrainedTokenizerFast.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.

# %%
bart_config = {'max_input_length':1024, 'trunc_input':True, 'max_output_length':100, 'min_output_length':1, 'length_penalty':5, 'num_beams':2}

# %%
df = pd.read_csv(data_path)
print(f' number of reviews is: {len(df)}')
df.head()
# Out:
#  number of reviews is: 20
#                                               Review  \
# 0  We love The Old Phoenix - this is the fourth t...
# 1  What a disappointment. We have wanted to stay ...
# 2  We walked over to Fenix from Loutro and stayed...
# 3  The Old Phoenix was the low point of our two w...
# 4  I had a fantastic time at Old-Phoenix!\n The b...
#
#                         distilbart (arielle) summary  \
# 0  We love The Old Phoenix - this is the fourth t...
# 1  Rooms are tired,  beds uncomfortable,  bathroo...
# 2  We stayed on the beach by the Old Phoenix in C...
# 3  The Old Phoenix was the low point of our two w...
# 4  The traditional regional Greek cuisine at the ...
#
#    (FILL IN MODEL NAME) summary  (FILL IN MODEL NAME) summary.1  \
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#    (FILL IN MODEL NAME) summary.2  (FILL IN MODEL NAME) summary.3  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    (FILL IN MODEL NAME) summary.4
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
df = df.rename(columns={"Review":"text"})

# %%
for i, row in df.iterrows():
    sequence = row.text
    input = tokenizer.encode(sequence, return_tensors="pt")
    # Generate Summary Text Ids
    summary_tokens = model.generate(
        input_ids=input,
        bos_token_id=model.config.bos_token_id,
        eos_token_id=model.config.eos_token_id,
        length_penalty=2.0,
        max_length=100,
        min_length=1,
        num_beams=4,
    )
    summary = tokenizer.decode(summary_tokens[0], skip_special_tokens=True)
    df.at[i, "summary"] = summary

# %%
summariztion_output_path = os.path.join(summariztion_output_dir, f'base-bart_{business_name}.csv')
df.to_csv(summariztion_output_path)

# %% [markdown]
# ### Comparison

# %%
test_df = pd.read_csv(os.path.join(summariztion_output_dir, f'updated_summary_test.csv'))

# %%
len(test_df.loc[test_df.better_summary=='a'])
# Out:
# 34

# %%
test_df
# Out:
#     Unnamed: 0                                               text  stars  \
# 0            0  We love The Old Phoenix - this is the fourth t...      5
# 1            1  What a disappointment. We have wanted to stay ...      1
# 2            2  We walked over to Fenix from Loutro and stayed...      5
# 3            3  The Old Phoenix was the low point of our two w...      1
# 4            4  I had a fantastic time at Old-Phoenix!\nThe be...      5
# 5            5  On the way from Marmara to Loutro I stopped fo...      1
# 6            6  If you are looking for a get away from it all ...      5
# 7            7  Amazing place with nice people running it! Ver...      5
# 8            8  When the small boat takes you into Finix Bay i...      5
# 9            9  I recommend this place for those who love to s...      5
# 10          10  Actually, you can read it all at the homepage ...      4
# 11          11  Didn't stay at the hotel but did eat at the re...      1
# 12          12  So now I'm back again at Old Phonix. If you wa...      5
# 13          13  A most beautiful and relaxing place, very frie...      5
# 14          14  I was a spectacular road but also a «hard driv...      4
# 15          15  Food was regular and good, typical greek and f...      3
# 16          16  It's our small paradise on earth. We  came aga...      5
# 17          17  My wife and I recently stayed at the Old Phoen...      5
# 18          18  This is the best vacation i have had, the hote...      5
# 19          19  I really don't understand how so many people l...      1
# 20          20  I stayed here with some friends for 6 weeks in...      5
# 21          21  You'll pass this place on your hike along this...      3
# 22          22  Beautiful location but if you want a wonderful...      3
# 23          23  The strong point of this hotel is its unique l...      3
# 24          24  Nice and calm place, less traffic than in Lout...      5
# 25          25  We love The Old Phoenix - this is the fourth t...      5
# 26          26  Second time here and will be back again. Spark...      5
# 27          27  Thought I'd died and gone to heaven! Loved it....      5
# 28          28  Secret hotel with its secret beach. Food is de...      5
# 29          29  We stayed here for a day. Cosy place, with rea...      5
# 30          30  Beautufil place, very nice people and a great ...      5
# 31          31  When we set off from Loutro we didn't know tha...      4
# 32          32  Beautiful family run hotel, was highly recomme...      5
# 33          33  ...nice place...nice cooking...nice cleaning.....      5
# 34          34  I want to say thank you very much for all the ...      5
# 35          35  cosy off-site hotel. 15 min walk to next villa...      5
# 36          36  We shared 3 dishes and thought they were all d...      5
# 37          37  Silent places with a amazing view and the road...      5
# 38          38  We stayed there for 5 days, excellent friendly...      5
# 39          39  One of the most beautiful place in Crete! Beau...      5
# 40          40  Amazing place.Quite and confortable rooms with...      5
# 41          41  By far the worst service anywhere on Crete and...      1
# 42          42  Great and friendly staff. Limited choice in re...      3
# 43          43  This is a beautiful spot. The E4 passes throug...      4
# 44          44  Very good accommodation and food in a beautifu...      5
# 45          45  Good hotel, beautiful views of Loutro bay from...      4
# 46          46  Amazing retreat with great swimming and specta...      5
# 47          47                              The beer was ice cold      5
# 48          48  The most peaceful place in Crete and the best ...      5
# 49          49  Perfect goat meat. Do not order fish or other ...      5
# 50          50  One of the cutest hotels ive ever been to + am...      5
# 51          51  Basic, but clean and comfortable with good foo...      4
# 52          52  Just need a bit more wifi signal so you could ...      4
# 53          53  Stopped off for a white wine and very nice wel...      4
# 54          54  Nice place for a breakfast or a dinner with a ...      3
# 55          55                 Beautiful spot, very good moussaka      5
# 56          56      simple rooms but the place is little paradise      4
#
#     months_ago                                          student a  \
# 0            5  The Old Phoenix is a traditional family-run pl...
# 1            4  We have wanted to stay here for years but it w...
# 2            6  We walked over to Fenix from Loutro and stayed...
# 3            5  The Old Phoenix was the low point of our two w...
# 4            8  I had a fantastic time at Old-Phoenix!\nThe be...
# 5            6  Loutro is a small town in central Crete.\nThe ...
# 6            6  We originally came here because it’s a great b...
# 7            7  Amazing place with nice people running it!\nVe...
# 8            6  Finix Bay is a wonderfully relaxing traditiona...
# 9           12  This is definitely the best place ever for sta...
# 10          12  The Old Phoenix is a really nice, very laid ba...
# 11           7  Didn't stay at the hotel but did eat at the re...
# 12          12  This is my review of Old Phonix from 2017.\nIt...
# 13          12  The family run hotel is very unique, with grea...
# 14          12  The Mossaka and the Greek salad tasted very go...
# 15          12  Food was regular and good, typical greek and f...
# 16          48  Yamas: Rooms are simple with a perfect sea vie...
# 17          48  My wife and I recently stayed at the Old Phoen...
# 18          48  The hotel is on an amazing beach and the resta...
# 19          24  A waiter constantly coming to our chair to dem...
# 20         108  If you like walking you can discover a lot in ...
# 21          12  The taverna looks inviting and as modern as Te...
# 22          12  Beautiful location but if you want a wonderful...
# 23          96  The strong point of this hotel is its unique l...
# 24          12  Nice and calm place, less traffic than in Lout...
# 25           5  The Old Phoenix is secluded and quiet, and the...
# 26          48  Second time here and will be back again.\nSpar...
# 27          48  No shops nearby, just sea, mountains, goats an...
# 28          84  Secret hotel with its secret beach.\nFood is d...
# 29          84  The road to this place is an great adventure.(...
# 30           6  Beautufil place, very nice people and a great ...
# 31          36  The village of Phoenix and Finikas bay are aro...
# 32          12  Beautiful family run hotel, was highly recomme...
# 33           5  ......nice place...nice cooking...nice cleanin...
# 34           6  I want to say thank you very much for all the ...
# 35         108  cosy off-site hotel.15 min walk to next villag...
# 36          12  We shared 3 dishes and thought they were all d...
# 37          12  Silent places with a amazing view and the road...
# 38          24  We stayed there for 5 days, excellent friendly...
# 39          48  One of the most beautiful places in Crete! Bea...
# 40          72  Amazing place. Quite and confortable rooms wit...
# 41          48  By far the worst service anywhere on Crete and...
# 42          24  Great and friendly staff. Limited choice in re...
# 43          11  The E4 passes through the Taverna.\nThis is a ...
# 44          24  Very good accommodation and food in a beautifu...
# 45          24  Good hotel, beautiful views of Loutro bay from...
# 46          72  Amazing retreat with great swimming and specta...
# 47           5  The beer was ice cold and the beer was cold.\n...
# 48          60  The most peaceful place in Crete and the best ...
# 49          72  Perfect goat meat. Do not order fish or other ...
# 50          84  One of the cutest hotels ive ever been to + am...
# 51          84  Basic, but clean and comfortable with good foo...
# 52          60  Just need a bit more wifi signal so you could ...
# 53          60  Stopped off for a white wine and very nice wel...
# 54          96  Nice place for a breakfast or dinner with a sh...
# 55          36           Beautiful spot, very good moussaka spot.
# 56          72      simple rooms but the place is little paradise
#
#                                             student b better_summary
# 0    this is the fourth time we’ve visited the old...              b
# 1    we have wanted to stay here for years but it ...              a
# 2    we walked over to stony beach from Loutro and...              b
# 3    the old Phoenix was the low point of our two ...              b
# 4    the staff was incredibly friendly and attenti...              a
# 5   the waiter came and said, "If you were in a hu...              b
# 6    the location and view is absolutely stunning....              a
# 7    the food was amazing, skip the menu and just ...              b
# 8    the small boat takes you into Finix Bay and t...              a
# 9    this is definitely the best place for those w...              b
# 10   |It is a really nice, very laid back place, b...              a
# 11   eat at Nikos Small Paradise instead of stayin...              b
# 12  old Phonix is a beautiful building in a beauti...              a
# 13   this family run hotel is very unique, with gr...              a
# 14   the last km was on a dirt road. but the view ...              b
# 15   food was regular and good, typical greek and ...              b
# 16   we came again with our teenagers for a perfec...              b
# 17   my wife and I recently stayed at the old Phoe...              b
# 18  the hotel is on an amazing beach and the resta...              a
# 19  the food was very disappointing. the staff in ...              b
# 20   stayed here with some friends for 6 weeks in ...              a
# 21  the taverna looks inviting and as modern as Te...              b
# 22   yoga group uses amplified vocals on the harbo...              b
# 23  the rooms were serviced once every three days ...              b
# 24   we had a very nice lunch with a Cretan salad ...              b
# 25   this is the fourth time we’ve visited the old...              a
# 26   second time here and will be back again. most...              b
# 27  en suite very basic, but adequate. food fresh ...              b
# 28  secret hotel with its secret beach. food is de...              a
# 29  4*4 WD is adviced. it is possible to rent kaya...              a
# 30  Beautufil place, very nice people and a great ...              a
# 31   the village of Phoenix and Finikas bay was ar...              a
# 32  a friend recommended a family run hotel so we ...              a
# 33  ...nice place...nice cooking...nice cleaning.....              b
# 34   i want to say thank you very much for all the...              a
# 35  cosy off-site hotel 15 min walk to next villag...              a
# 36   we shared 3 dishes and thought they were all ...              b
# 37  only a few parking lots available only for gue...              a
# 38   we stayed there for 5 days, excellent friendl...              a
# 39  the food is fresh and tastefull. 100% The 1st ...              a
# 40  the waiters are frendly and nice. The waiters ...              b
# 41  the staff were rude and lazy... it’s so a sham...              a
# 42  great and friendly staff. Limited choice in re...              a
# 43                 the E4 passes through the Taverna.              b
# 44  good accommodation and food in a beautiful are...              a
# 45  good hotel, beautiful views of Loutro bay from...              a
# 46   great retreat with great swimming and spectac...              a
# 47  the beer was ice cold. the beer was ice cold. ...              a
# 48  the most peaceful place in Crete and the best ...              a
# 49  perfect goat meat. Do not order fish or other ...              a
# 50   one of the cutest hotels ive ever been to + a...              a
# 51   basic, but clean and comfortable with good fo...              a
# 52   need a bit more wifi signal so you could work...              a
# 53  stopped off for a white wine and very nice wel...              a
# 54   Nice place for a breakfast or a dinner with a...              b
# 55  beautiful spot, very good moussaka spot, very ...              a
# 56  simple rooms but the place is little paradise....              a

# %%
print(f"bart - {len(test_df.loc[test_df.better_summary=='a'])}")
print(f"t5 - {len(test_df[test_df.better_summary=='b'])}")
# Out:
# bart - 34
# t5 - 23

# %% [markdown]
# ### Evaluating summarization of texts

# %% [markdown]
# #### 1) Evaluate using bert score

# %%
# !pip install bert_score

# %%
# ! pip install evaluate

# %%
references = df.summary[0]
references
# Out:
# 'The Old Phoenix is secluded and quiet, and the swimming in the bay is sublime.\nIf you’re expecting five-star luxury, go somewhere else; this is a traditional …'

# %%
from evaluate import load
bertscore = load("bertscore")
hypotheses = [df.text[0]]
references = [df.summary[0]]
results= bertscore.compute(predictions=hypotheses, references=references,  model_type="distilbert-base-uncased")

# %%
print(results)
# Out:
# {'precision': [0.88301682472229], 'recall': [0.9785053133964539], 'f1': [0.9283120036125183], 'hashcode': 'distilbert-base-uncased_L5_no-idf_version=0.3.12(hug_trans=4.35.2)'}

# %% [markdown]
# #### 2) Evaluate using ROUGE (Recall-Oriented Understudy for Gisting Evaluation)

# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in c:\users\danatal\anaconda3\envs\dana\lib\site-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
# Import the load function from the evaluate module
from evaluate import load

# Loading the 'rouge' metric from the library
rouge = load('rouge')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\DanaTal\projects\nlp\Bridezilla_NLP\summarize\summarize.ipynb Cell 29 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/summarize.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> from evaluate import load
#       <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/summarize.ipynb#X55sZmlsZQ%3D%3D?line=3'>4</a> # Loading the 'rouge' metric from the library
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DanaTal/projects/nlp/Bridezilla_NLP/summarize/summarize.ipynb#X55sZmlsZQ%3D%3D?line=4'>5</a> rouge = load('rouge')
#
# File c:\Users\DanaTal\anaconda3\envs\dana\Lib\site-packages\evaluate\loading.py:748, in load(path, config_name, module_type, process_id, num_process, cache_dir, experiment_id, keep_in_memory, download_config, download_mode, revision, **init_kwargs)
#     703 """Load a [`~evaluate.EvaluationModule`].
#     704
#     705 Args:
#    (...)
#     745     ```
#     746 """
#     747 download_mode = DownloadMode(download_mode or DownloadMode.REUSE_DATASET_IF_EXISTS)
# --> 748 evaluation_module = evaluation_module_factory(
#     749     path, module_type=module_type, revision=revision, download_config=download_config, download_mode=download_mode
#     750 )
#     751 evaluation_cls = import_main_class(evaluation_module.module_path)
#     752 evaluation_instance = evaluation_cls(
#     753     config_name=config_name,
#     754     process_id=process_id,
#    (...)
#     760     **init_kwargs,
#     761 )
#
# File c:\Users\DanaTal\anaconda3\envs\dana\Lib\site-packages\evaluate\loading.py:680, in evaluation_module_factory(path, module_type, revision, download_config, download_mode, force_local_path, dynamic_modules_path, **download_kwargs)
#     678                 pass
#     679         if not isinstance(e1, (ConnectionError, FileNotFoundError)):
# --> 680             raise e1 from None
#     681         raise FileNotFoundError(
#     682             f"Couldn't find a module script at {relative_to_absolute_path(combined_path)}. "
#     683             f"Module '{path}' doesn't exist on the Hugging Face Hub either."
#     684         ) from None
#     685 else:
#
# File c:\Users\DanaTal\anaconda3\envs\dana\Lib\site-packages\evaluate\loading.py:639, in evaluation_module_factory(path, module_type, revision, download_config, download_mode, force_local_path, dynamic_modules_path, **download_kwargs)
#     631 for current_type in ["metric", "comparison", "measurement"]:
#     632     try:
#     633         return HubEvaluationModuleFactory(
#     634             f"evaluate-{current_type}/{path}",
#     635             revision=revision,
#     636             download_config=download_config,
#     637             download_mode=download_mode,
#     638             dynamic_modules_path=dynamic_modules_path,
# --> 639         ).get_module()
#     640     except ConnectionError:
#     641         pass
#
# File c:\Users\DanaTal\anaconda3\envs\dana\Lib\site-packages\evaluate\loading.py:489, in HubEvaluationModuleFactory.get_module(self)
#     486         raise err
#     488 imports = get_imports(local_path)
# --> 489 local_imports = _download_additional_modules(
#     490     name=self.name,
#     491     base_path=hf_hub_url(path=self.name, name="", revision=revision),
#     492     imports=imports,
#     493     download_config=self.download_config,
#     494 )
#     495 # copy the script and the files in an importable directory
#     496 dynamic_modules_path = self.dynamic_modules_path if self.dynamic_modules_path else init_dynamic_modules()
#
# File c:\Users\DanaTal\anaconda3\envs\dana\Lib\site-packages\evaluate\loading.py:265, in _download_additional_modules(name, base_path, imports, download_config)
#     263         needs_to_be_installed.add((library_import_name, library_import_path))
#     264 if needs_to_be_installed:
# --> 265     raise ImportError(
#     266         f"To be able to use {name}, you need to install the following dependencies"
#     267         f"{[lib_name for lib_name, lib_path in needs_to_be_installed]} using 'pip install "
#     268         f"{' '.join([lib_path for lib_name, lib_path in needs_to_be_installed])}' for instance'"
#     269     )
#     270 return local_imports
#
# ImportError: To be able to use evaluate-metric/rouge, you need to install the following dependencies['absl', 'rouge_score'] using 'pip install # Here to have a nice missing dependency error message early on rouge_score' for instance'

# %%
import torch
from rouge import Rouge

# Define the generated summary and the reference summary
generated_summary = df.text[0]
reference_summary = df.summary[0]
# Initialize the ROUGE object
rouge = Rouge()
# Calculate ROUGE for the generated and reference summaries
scores = rouge.get_scores(generated_summary, reference_summary)
# Print the results
print(scores)
# Out:
# [{'rouge-1': {'r': 1.0, 'p': 0.6486486486486487, 'f': 0.7868852411287289}, 'rouge-2': {'r': 0.9259259259259259, 'p': 0.5952380952380952, 'f': 0.7246376763957153}, 'rouge-l': {'r': 1.0, 'p': 0.6486486486486487, 'f': 0.7868852411287289}}]

# %%
# ! pip install absl-py rouge_score

# %%
# Import the load function from the evaluate module
from evaluate import load

# Loading the 'rouge' metric from the library
rouge = load('rouge')

# Define your predictions and references
predictions = [df.text[0]]
references = [df.summary[0]]

# Compute the scores
results = rouge.compute(predictions=predictions, references=references)

# Print the scores
print(results)
# Out:
# {'rouge1': 0.763157894736842, 'rouge2': 0.7027027027027025, 'rougeL': 0.763157894736842, 'rougeLsum': 0.763157894736842}

# %%
def evaluate_df(pred, reference, model):
# Out:
# {'rouge1': 0.763157894736842,
#  'rouge2': 0.7027027027027025,
#  'rougeL': 0.763157894736842,
#  'rougeLsum': 0.763157894736842}

# %%
# Out:
# dict_keys(['rouge-1', 'rouge-2', 'rouge-l'])

# %% [markdown]
# #### Evaluete models

# %%
summariztion_output_dir
# Out:
# 'c:\\Users\\DanaTal\\projects\\nlp\\Bridezilla_NLP\\outputs\\summarization'

# %%
bart_path = glob(summariztion_output_dir + '\\*bart*.csv')[0]
t5_path = glob(summariztion_output_dir + '\\*t5*.csv')[0]
t5_path
# Out:
# 'c:\\Users\\DanaTal\\projects\\nlp\\Bridezilla_NLP\\outputs\\summarization\\t5-small.csv'

# %%
bart = pd.read_csv(bart_path)
t5 = pd.read_csv(t5_path)

# %%
from copy import deepcopy
evaluate_df = deepcopy(bart)
evaluate_df = evaluate_df.rename(columns={"summary": "bart"}).reset_index(drop=True)
evaluate_df = pd.concat([evaluate_df, t5["summary"]], axis=1).reset_index(drop=True)
evaluate_df = evaluate_df.rename(columns={"summary": "t5"}).reset_index(drop=True)

# %%
evaluate_df.head()
# Out:
#                                                 text  stars  months_ago  \
# 0  We love The Old Phoenix - this is the fourth t...      5           5
# 1  What a disappointment. We have wanted to stay ...      1           4
# 2  We walked over to Fenix from Loutro and stayed...      5           6
# 3  The Old Phoenix was the low point of our two w...      1           5
# 4  I had a fantastic time at Old-Phoenix!\nThe be...      5           7
#
#                                                 bart  \
# 0  The Old Phoenix is secluded and quiet, and the...
# 1  We have wanted to stay here for years but it w...
# 2  We walked over to Fenix from Loutro and stayed...
# 3  The Old Phoenix was the low point of our two w...
# 4  "The beautiful beach on site provided the perf...
#
#                                                   t5
# 0   this is the fourth time we’ve visited the old...
# 1   we have wanted to stay here for years but it ...
# 2   we walked over to stony beach from Loutro and...
# 3   the old Phoenix was the low point of our two ...
# 4  the beautiful beach on site provided the perfe...
